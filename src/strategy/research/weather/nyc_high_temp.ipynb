# %%
from strategy.utils import ColeDBInterface


db = ColeDBInterface()

df = db.read_bbo_df("HIGHNY-24APR25-B59.5")
# Out:
# /Users/kamyarghiam/Desktop/kalshi_bot/src/strategy/utils.py:25: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   import tqdm.autonotebook as tqdm

# %%
import matplotlib.pyplot as plt 

plt.plot(df.ts, df.yes_ask_price, color= "blue")
plt.plot(df.ts, df.yes_bid_price, color = "red")

# %%
from datetime import datetime
# Data from april 25th 
temps = ['51', '47', '46', '45', '44', '43', '43', '43', '46', '47', '51', '54', '56', '57', '59', '57', '53', '52', '49', '47', '46', '46', '45', '45']
times = [datetime(2024, 4, 25, 0, 51), datetime(2024, 4, 25, 1, 51), datetime(2024, 4, 25, 2, 51), datetime(2024, 4, 25, 3, 51), datetime(2024, 4, 25, 4, 51), datetime(2024, 4, 25, 5, 51), datetime(2024, 4, 25, 6, 51), datetime(2024, 4, 25, 7, 51), datetime(2024, 4, 25, 8, 51), datetime(2024, 4, 25, 9, 51), datetime(2024, 4, 25, 10, 51), datetime(2024, 4, 25, 11, 51), datetime(2024, 4, 25, 12, 51), datetime(2024, 4, 25, 13, 51), datetime(2024, 4, 25, 14, 51), datetime(2024, 4, 25, 15, 51), datetime(2024, 4, 25, 16, 51), datetime(2024, 4, 25, 17, 51), datetime(2024, 4, 25, 18, 51), datetime(2024, 4, 25, 19, 51), datetime(2024, 4, 25, 20, 51), datetime(2024, 4, 25, 21, 51), datetime(2024, 4, 25, 22, 51), datetime(2024, 4, 25, 23, 51)]
times = [d.timestamp() for d in times]

# %%
plt.plot(df.ts, df.yes_ask_price, color= "blue")
# plt.plot(df.ts, df.yes_bid_price, color = "red")
plt.scatter(times[8:17], temps[8:17], color = "black")
plt.scatter(times[14:15], temps[14:15], color = "red")
